# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Benedetta\\Desktop\\Criticality in barrel cortex\\EEG avalanche analysis'

# %%
os.listdir('../../../Downloads/avalanches_in_silences/avalanches_silence1/');

# %%
## try on pooled data

# %%
pwd
# Out:
# 'C:\\Users\\Benedetta\\Desktop\\Criticality in barrel cortex\\EEG avalanche analysis'

# %%
value = False

plt.rcParams['font.size'] = 16
fig = plt.figure(figsize = (12,12))
axs = fig.add_subplot(2,2,1)
axd = fig.add_subplot(2,2,2)
axsh = fig.add_subplot(2,2,3)
axdh = fig.add_subplot(2,2,4)
alphas = []

taus = []
totals = []
totald  =[]
i = 0
os.chdir('../../../Downloads/avalanches_in_silences/avalanches_silence1/')
for file in os.listdir():
    if 'th2' in file:
        print(file)
        lista = open(file, 'r')
        datContent = [i.split() for i in lista.readlines()]
        newdata = np.asarray(datContent, dtype = float)
        s = newdata[:,0]
        d = newdata[:,1]
        data = s
        fit = pwl.Fit(data,xmin =(1,100),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
        exp = fit.power_law.alpha
        pwl.plot_pdf(data,color = 'tab:red', marker = '.', ax = axs, alpha = 0.3)
        #fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--', ax = axs)
        axs.set_xlabel(r'Avalanche sizes')
        axs.set_ylabel(r'pdf')
        #axs.annotate("alpha= {}".format(round(exp,2)),[0.8,0.5])
        alphas.append(exp)
        data = d
        fit = pwl.Fit(data,xmin =(0,0.05),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
        exp = fit.power_law.alpha
        pwl.plot_pdf(data,color = 'tab:green', marker = '.', ax = axd, alpha = 0.3)
        #fit.power_law.plot_pdf(data,color = 'tab:green' ,linestyle = '--', ax = axd, alpha = 0.6)
        axd.set_xlabel(r'Avalanche lifetimes')
        axd.set_ylabel(r'pdf')
        #axd.annotate("alpha= {}".format(round(exp,2)),[0.8,0.5])
        taus.append(exp)
        #if i == 1: break
        axsh.hist(alphas, bins = 15, color = 'red', alpha = .5, density = True)
        axsh.set_xlabel('Alphas')
        axsh.set_ylabel('pdf')
        
        axdh.hist(taus, bins = 15, color = 'green', alpha = .5, density = True)
        axdh.set_xlabel('Taus')
        axdh.set_ylabel('pdf')
        
        
        
        totals += newdata[:,0].tolist()
        totald += newdata[:,1].tolist()
        i+=1
        
        

totals = np.asarray(totals)
totald = np.asarray(totald)

data = totals
fit = pwl.Fit(data,xmin =(1,100),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
exp = fit.power_law.alpha
axs.annotate("Pooled alpha= {}".format(round(exp,2)),[0.8,0.5], xycoords = 'axes fraction',fontsize = 11)

pwl.plot_pdf(data,color = 'tab:red', marker = '.', ax = axs)
fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--',ax = axs)


data = totald
fit = pwl.Fit(data,xmin =(0,0.05),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value,)
exp = fit.power_law.alpha
axd.annotate("Pooled alpha= {}".format(round(exp,2)),[0.8,0.5], xycoords = 'axes fraction', fontsize = 11)
pwl.plot_pdf(data,color = 'tab:green', marker = '.', ax = axd)
fit.power_law.plot_pdf(data,color = 'tab:green' ,linestyle = '--', ax = axd)

        
plt.tight_layout()
# Out:
# bb10th2.dat
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb11th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb12th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb16th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb17th2.datss: 99%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb18th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb19th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb21th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb30th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb33th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb35th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb37th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb38th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb40th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb45th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb47th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb49th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb52th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb56th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb58th2.datss: 99%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb5th2.datess: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb60th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb62th2.datss: 99%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb66th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb67th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb68th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb6th2.datess: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb71th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb9th2.datess: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# xmin progress: 99%

# %%
value = False

plt.rcParams['font.size'] = 16
fig = plt.figure(figsize = (12,12))
fig.suptitle('Second silence')
axs = fig.add_subplot(2,2,1)
axd = fig.add_subplot(2,2,2)
axsh = fig.add_subplot(2,2,3)
axdh = fig.add_subplot(2,2,4)
alphas = []

taus = []
totals = []
totald  =[]
i = 0
os.chdir('../../../Downloads/avalanches_in_silences/avalanches_silence2/')
for file in os.listdir():
    if 'th2' in file:
        print(file)
        lista = open(file, 'r')
        datContent = [i.split() for i in lista.readlines()]
        newdata = np.asarray(datContent, dtype = float)
        s = newdata[:,0]
        d = newdata[:,1]
        data = s
        fit = pwl.Fit(data,xmin =(1,100),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
        exp = fit.power_law.alpha
        pwl.plot_pdf(data,color = 'tab:red', marker = '.', ax = axs, alpha = 0.3)
        #fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--', ax = axs)
        axs.set_xlabel(r'Avalanche sizes')
        axs.set_ylabel(r'pdf')
        #axs.annotate("alpha= {}".format(round(exp,2)),[0.8,0.5])
        alphas.append(exp)
        data = d
        fit = pwl.Fit(data,xmin =(0,0.05),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
        exp = fit.power_law.alpha
        pwl.plot_pdf(data,color = 'tab:green', marker = '.', ax = axd, alpha = 0.3,)
        #fit.power_law.plot_pdf(data,color = 'tab:green' ,linestyle = '--', ax = axd, alpha = 0.6)
        axd.set_xlabel(r'Avalanche lifetimes')
        axd.set_ylabel(r'pdf')
        #axd.annotate("alpha= {}".format(round(exp,2)),[0.8,0.5])
        taus.append(exp)
        #if i == 1: break
        axsh.hist(alphas, bins = 15, color = 'red', alpha = .5, discrete = True)
        axsh.set_xlabel('Alphas')
        axsh.set_ylabel('pdf')
        axdh.hist(taus, bins = 15, color = 'green', alpha = .5, discrete = True)
        axdh.set_xlabel('Taus')
        axdh.set_ylabel('pdf')
        
        
        totals += newdata[:,0].tolist()
        totald += newdata[:,1].tolist()
        i+=1
        
        

totals = np.asarray(totals)
totald = np.asarray(totald)

data = totals
fit = pwl.Fit(data,xmin =(1,100),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
exp = fit.power_law.alpha
axs.annotate("Pooled alpha= {}".format(round(exp,2)),[0.8,0.5], xycoords = 'axes fraction',fontsize = 11)

pwl.plot_pdf(data,color = 'tab:red', marker = '.', ax = axs)
fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--',ax = axs)


data = totald
fit = pwl.Fit(data,xmin =(0,0.05),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value,)
exp = fit.power_law.alpha
axd.annotate("Pooled alpha= {}".format(round(exp,2)),[0.8,0.5], xycoords = 'axes fraction',fontsize = 11)
pwl.plot_pdf(data,color = 'tab:green', marker = '.', ax = axd)
fit.power_law.plot_pdf(data,color = 'tab:green' ,linestyle = '--', ax = axd)

        
plt.tight_layout()
# Out:
# bb11th2.dat
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb12th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb16th2.datss: 97%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb17th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb18th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb19th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb25th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb30th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb33th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb34th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb35th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb37th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb39th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb40th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb45th2.datss: 99%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb47th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb49th2.datss: 97%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb52th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb53th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb56th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb57th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb58th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb5th2.datess: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb63th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb66th2.datss: 97%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb67th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb68th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb69th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb6th2.datess: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb71th2.datss: 98%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# bb9th2.datess: 97%
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# xmin progress: 99%

# %%
#s = newdata[:,0]
#d = newdata[:,1]

# %%
len(s), len(d)
# Out:
# (17345, 17345)

# %%
import powerlaw as pwl ### Jeff Alstott Module
import numpy as np
import matplotlib.pyplot as plt
value = False
### discrete = False for continuous distributions

def generate_pwl(xmax, n, func, value = True):
    data = []
    for i in range(n):
        a= func.generate_random(n = 1,estimate_discrete= value) 
        if a <= xmax:
            data.append(a[0])
    return np.asarray(data)

# %%
data = s

plt.rcParams['font.size'] = 18
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
fit = pwl.Fit(data,xmin =(1,100),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
exp = fit.power_law.alpha
print('Alpha is: ', exp)
pwl.plot_pdf(data,color = 'tab:red', marker = 'o')
fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--')
ax.set_xlabel(r'Data')
ax.set_ylabel(r'pdf')
ax.text(100,0.001,"alpha= {}".format(round(exp,2)))
# Out:
# Calculating best minimal value for power law fit
# Alpha is:  1.8751950878969206
# Text(100, 0.001, 'alpha= 1.88')

# %% [markdown]
# ## Calculate PValue

# %%
#fit = pwl.Fit(artif_data,xmax = max(artif_data),parameter_range= {"alpha":[1,4]},discrete = True)
#fit.generat

# %%
len(data)
# Out:
# 16501

# %%
fit = pwl.Fit(data,xmin = (1,100),xmax = max(data),parameter_range= {"alpha":[1,4]},discrete = value)
#func = pwl.Power_Law(xmin = fit.power_law.xmin, xmax = fit.power_law.xmax, parameters = [fit.power_law.alpha], discrete = True)
## (fit  racchiude tutti i Fit di tutte le funzioni, l'xmin è minimizzato solo per il power law fit)
#n = 1000
Ds =[]
xmin_found = fit.power_law.xmin
xmax = max(data)
n = len(data)
#func.power_law.
num_iter = 100
for f in range(num_iter):
    #xmax,alpha = 1,10000,1.5
    gen = generate_pwl(xmax,n, fit.power_law)
    fit2 = pwl.Fit(gen,xmin = (xmin_found, xmin_found +1),xmax =xmax,parameter_range= {"alpha":[1,4]},discrete = value)
    Ds.append(fit2.power_law.D)
# Out:
# Calculating best minimal value for power law fit
# xmin progress: 00%
# KeyboardInterrupt

# %%
Dmyfit =  fit.power_law.D
Ds = np.array(Ds)
pvalue = np.sum(Dmyfit <= Ds)/len(Ds)
pvalue # must be higher than e.g. 0.1
## forse mi dava sempre 1 anche in tesi
# Out:
# 0.59

# %%
plt.hist(Ds, bins = 34,color = 'grey')
plt.vlines(Dmyfit, 0,10,color ='red')
plt.xlabel('Ds')
plt.ylabel('pdf');
## il range di fit è piccolo..

# %% [markdown]
# ## Martin Gerlach Testing Statistical Laws in Complex Systems package

# %% [markdown]
# ## (I have renaimed powerlaw.py module into power.py otherwise there is conflict with powerlaw by Alstott)

# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.cm as cm
cmap = cm.tab10

# %%
os.chdir("C:/Users/Benedetta/Desktop/Criticality in barrel cortex/")

# %%
from data_io_ts import *
from stats import xdata_to_xnx, x_autocorr_sm_ext
from powerlaw_fit import *


# import setup for figure layout (see src/modules_plotting.py to customize)
from modules_plotting import *

# %%
xmin_found = fit.power_law.xmin
xmax = max(data)
n = len(data)

# %%
x_data = data
xmin = xmin_found
x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)

N = np.sum(nx)
px = nx/N
Fx = 1-np.cumsum(px) ### questo passaggio qui con i dati continui fa cose strane

## Fit: powerlaw
if value == True:
    print('here')
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_disc(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_disc(x,xmin,xmax,alpha)
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_cont(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_cont(x,xmin,xmax,alpha) ### GIUSTO COSì
alpha
# Out:
# 1.8139070249637355

# %%
xmin_found
# Out:
# 98.85675287746493

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

## Plot the distribution
x_ = x
y_ = Fx

c_ = cmap(0)
ax.plot(x_,y_,marker='o',ms=2,lw=0,c = c_,label = 'Data')

## Plot the fit
c_ = cmap(1)
x_ = x
y_ = Fx_fit
plt.plot(x_,y_,lw=2,c=c_, label = 'Fit')

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$x$')#,labelpad=0)
ax.set_ylabel(r'$p(x)$')
ax.set_ylim(10**-6,10**0)
# Out:
# (1e-06, 1)

# %%
xmin_found
# Out:
# 78.35233431842437

# %%
x_data = data
xmin = xmin_found
x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)

N = np.sum(nx)
px = nx/N
Fx = 1-np.cumsum(px)

## Fit: powerlaw
if value == True:
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_disc(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_disc(x,xmin,xmax,alpha) ### GIUSTO COSì
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_cont(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_cont(x,xmin,xmax,alpha)


fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

## Plot the distribution
x_ = x
y_ = px

c_ = cmap(0)
ax.plot(x_,y_,marker='o',ms=2,lw=0.1,c = c_,label = 'Data')

## Plot the fit
c_ = cmap(1)
x_ = x
y_ = px_fit
plt.plot(x_,y_,lw=2,c=c_, label = 'Fit')

ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(10**-3,10**-1)

ax.set_xlabel(r'$x$')#,labelpad=0)
ax.set_ylabel(r'$p(x)$')
# Out:
# Text(0, 0.5, '$p(x)$')

# %%
np.random.seed(42)

nrep = 10**3
q1,q2 = 1,99
result = x_autocorr_sm_ext(np.log(x_data),nrep=nrep,q=[q1,q2])
x = result['tau']
y_mu,y_1,y_2 = result['C']
y_mu_rand,y_1_rand,y_2_rand = result['C_rand']

## here we calculate from t=0,1,...,t^* where t^* is the first point
## where true C(t) is within the q-percentiles of the random

# ind_t_star = np.where( (y_mu<=y_2_rand)&(y_mu>=y_1_rand) )[0][1]
ind_t_star = np.where(y_1<=y_2_rand)[0][2]
tau_star = x[ind_t_star]

print('Autocorrelation time: ',tau_star)
# Out:
# Autocorrelation time:  112

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

alpha_val = .5
## Plot the empirical autocorrelation
x_ = x
y_ = y_mu
z1_ = y_1
z2_ = y_2
c_ = cmap(0)
ax.plot(x_,y_,c = c_,lw=lw, label = 'Data')
ax.fill_between(x_,z1_,z2_,color=c_,alpha=alpha_val,lw=0)



## Plot the randomized autocorrelation
x_ = x
y_ = y_mu_rand
z1_ = y_1_rand
z2_ = y_2_rand
c_ = cmap(1)
ax.plot(x_,y_,c = c_,lw=lw, label = 'Randomized')
ax.fill_between(x_,z1_,z2_,color=c_,alpha=alpha_val,lw=0)


ax.plot([tau_star,tau_star],[-1,1],lw=1,color='black',ls=':')


## Layout stuff
ax.legend(loc='upper right')

ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel(r'Time Lag, $\tau$')#,labelpad=0)
ax.set_ylabel(r'$C(\tau)$')
#ax.set_ylim(-0.1,0.2)


x_annot_tau = 0.8
y_annot_tau = 0.6
ax.annotate(r'$\tau^*=%s$'%(int(tau_star)),xy=(x_annot_tau,y_annot_tau),xycoords = 'axes fraction')
# Out:
# Text(0.8, 0.6, '$\\tau^*=112$')

# %%
nrep_synth = 100 ## number of synthetic datasets to generate for empirical p-value (i have called this niter above)

x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)
if value == True:
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
    
    
alpha = result['alpha'] ## fitted parameter alpha
pval = result['pval'] ## p-value
KS = result['KS'] ## KS-distance

print('Original dataset. N = %s'%(N))
print('Empirical p-value from %s synthetic datasets: '%(nrep_synth), pval)
# Out:
# Original dataset. N = 8644
# Empirical p-value from 100 synthetic datasets:  0.0

# %%
p_sub = 1./tau_star ## 0 ... 1 (keep nothing ... keep all); we set 1/tau_star
N_sub = int(p_sub*N)
nrep_synth = 100 ## number of synthetic datasets to generate for empirical p-value


## subsample -- take N_sub samples from x_data without replacement
x_data_sub = np.random.choice(x_data,size=N_sub,replace=False)
x,nx = xdata_to_xnx(x_data_sub,norm=False,xmin=xmin,xmax=xmax)
result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth) if value else fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)

alpha = result['alpha'] ## fitted parameter alpha
pval = result['pval'] ## p-value
KS = result['KS'] ## KS-distance

print(r'Subsampled dataset: n = %s (n/N ~ %s)'%(N_sub,p_sub)) 
print('Empirical p-value from %s synthetic datasets: '%(nrep_synth), pval)
# Out:
# Subsampled dataset: n = 77 (n/N ~ 0.008928571428571428)
# Empirical p-value from 100 synthetic datasets:  0.18999999999999995

# %%
len(d)
# Out:
# 1063

# %% [markdown]
# ## Durations

# %%
data = d
### GREAT VARIABILITY IN EXPONENTS DEPENDING ON BOUND IN XMIN

plt.rcParams['font.size'] = 18
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
fit = pwl.Fit(data,xmin = (0,0.02),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
exp = fit.power_law.alpha
print('Alpha is: ', exp)
pwl.plot_pdf(data,color = 'tab:red', marker = 'o')
fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--')
ax.set_xlabel(r'Data')
ax.set_ylabel(r'pdf')
ax.text(100,0.001,"alpha= {}".format(round(exp,2)))
# Out:
# Calculating best minimal value for power law fit
# Alpha is:  1.9153547396865918
# Text(100, 0.001, 'alpha= 1.92')

# %%
data = d
### GREAT VARIABILITY IN EXPONENTS DEPENDING ON BOUND IN XMIN

plt.rcParams['font.size'] = 18
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
fit = pwl.Fit(data,xmin =(0,0.05),xmax= max(data),parameter_range= {"alpha":[1,4]},discrete = value)
exp = fit.power_law.alpha
print('Alpha is: ', exp)
pwl.plot_pdf(data,color = 'tab:red', marker = 'o')
fit.power_law.plot_pdf(data,color = 'tab:red' ,linestyle = '--')
ax.set_xlabel(r'Data')
ax.set_ylabel(r'pdf')
ax.text(100,0.001,"alpha= {}".format(round(exp,2)))
# Out:
# Calculating best minimal value for power law fit
# Alpha is:  2.237902748607576
# Text(100, 0.001, 'alpha= 2.24')

# %% [markdown]
# ## Calculate PValue

# %%
#fit = pwl.Fit(artif_data,xmax = max(artif_data),parameter_range= {"alpha":[1,4]},discrete = True)
#fit.generat

# %%
len(data)
# Out:
# 353

# %%
1/0.65

# %%
### number of time bins
### silence 1 and silence 2

# %%
fit = pwl.Fit(data,xmin = (0,0.02),xmax = max(data),parameter_range= {"alpha":[1,4]},discrete = value)
#func = pwl.Power_Law(xmin = fit.power_law.xmin, xmax = fit.power_law.xmax, parameters = [fit.power_law.alpha], discrete = True)
## (fit  racchiude tutti i Fit di tutte le funzioni, l'xmin è minimizzato solo per il power law fit)
#n = 1000
Ds =[]
xmin_found = fit.power_law.xmin
xmax = max(data)
n = len(data)
#func.power_law.
num_iter = 100
for f in range(num_iter):
    #xmax,alpha = 1,10000,1.5
    gen = generate_pwl(xmax,n, fit.power_law)
    fit2 = pwl.Fit(gen,xmin = (xmin_found, xmin_found +1),xmax =xmax,parameter_range= {"alpha":[1,4]},discrete = value)
    Ds.append(fit2.power_law.D)
# Out:
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# xmin progress: 26%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 14
#      11 for f in range(num_iter):
#      12     #xmax,alpha = 1,10000,1.5
#      13     gen = generate_pwl(xmax,n, fit.power_law)
# ---> 14     fit2 = pwl.Fit(gen,xmin = (xmin_found, xmin_found +1),xmax =xmax,parameter_range= {"alpha":[1,4]},discrete = value)
#      15     Ds.append(fit2.power_law.D)
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:150, in Fit.__init__(self, data, discrete, xmin, xmax, verbose, fit_method, estimate_discrete, discrete_approximation, sigma_threshold, parameter_range, fit_optimizer, xmin_distance, xmin_distribution, **kwargs)
#     147     if verbose:
#     148         print("Calculating best minimal value for {} fit".format(
#     149             xmin_distribution.replace('_',' '), file=sys.stderr))
# --> 150     self.find_xmin()
#     152 self.data = self.data[self.data>=self.xmin]
#     153 self.n = float(len(self.data))
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:246, in Fit.find_xmin(self, xmin_distance)
#     243     return getattr(pl, xmin_distance), pl.alpha, pl.sigma, pl.in_range()
#     245 num_xmins = len(xmins)
# --> 246 fits = asarray(list(map(fit_function, xmins, arange(num_xmins), repeat(num_xmins, num_xmins))))
#     247 # logging.warning(fits.shape)
#     248 setattr(self, xmin_distance+'s', fits[:,0])
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:231, in Fit.find_xmin.<locals>.fit_function(xmin, idx, num_xmins)
#     229 def fit_function(xmin, idx, num_xmins):
#     230     print('xmin progress: {:02d}%'.format(int(idx/num_xmins * 100)), end='\r')
# --> 231     pl = self.xmin_distribution(xmin=xmin,
#     232                    xmax=self.xmax,
#     233                    discrete=self.discrete,
#     234                    estimate_discrete=self.estimate_discrete,
#     235                    fit_method=self.fit_method,
#     236                    data=self.data,
#     237                    parameter_range=self.parameter_range,
#     238                    parent_Fit=self)
#     239     if not hasattr(pl, 'sigma'):
#     240         pl.sigma = nan
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:1123, in Power_Law.__init__(self, estimate_discrete, **kwargs)
#    1121 def __init__(self, estimate_discrete=True, **kwargs):
#    1122     self.estimate_discrete = estimate_discrete
# -> 1123     Distribution.__init__(self, **kwargs)
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:614, in Distribution.__init__(self, xmin, xmax, discrete, fit_method, data, parameters, parameter_range, initial_parameters, discrete_approximation, parent_Fit, **kwargs)
#     611     self.parameters(parameters)
#     613 if parameter_range:
# --> 614     self.parameter_range(parameter_range)
#     616 if initial_parameters:
#     617     self._given_initial_parameters(initial_parameters)
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:914, in Distribution.parameter_range(self, r, initial_parameters)
#     911     self._given_initial_parameters = initial_parameters
#     913 if self.parent_Fit:
# --> 914     self.fit(self.parent_Fit.data)
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:1161, in Power_Law.fit(self, data)
#    1159     self.KS(data)
#    1160 else:
# -> 1161     Distribution.fit(self, data, suppress_output=True)
#    1163 if not self.in_range():
#    1164     self.noise_flag=True
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:643, in Distribution.fit(self, data, suppress_output)
#     640         return self.D
#     641 from scipy.optimize import fmin
#     642 parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
# --> 643     fmin(
#     644         lambda params: fit_function(params),
#     645         self.initial_parameters(data),
#     646         full_output=1,
#     647         disp=False)
#     648 self.parameters(parameters)
#     649 if not self.in_range():
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:695, in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     586 """
#     587 Minimize a function using the downhill simplex algorithm.
#     588
#    (...)
#     685
#     686 """
#     687 opts = {'xatol': xtol,
#     688         'fatol': ftol,
#     689         'maxiter': maxiter,
#    (...)
#     692         'return_all': retall,
#     693         'initial_simplex': initial_simplex}
# --> 695 res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     696 if full_output:
#     697     retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:870, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     868 if bounds is not None:
#     869     xr = np.clip(xr, lower_bound, upper_bound)
# --> 870 fxr = func(xr)
#     871 doshrink = 0
#     873 if fxr < fsim[0]:
#
# File ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py:569, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     567 ncalls[0] += 1
#     568 # A copy of x is sent to the user function (gh13740)
# --> 569 fx = function(np.copy(x), *(wrapper_args + args))
#     570 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571 # backwards-compatibility, also allow np.array([1.3]),
#     572 # np.array([[1.3]]) etc.
#     573 if not np.isscalar(fx):
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:644, in Distribution.fit.<locals>.<lambda>(params)
#     640         return self.D
#     641 from scipy.optimize import fmin
#     642 parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
#     643     fmin(
# --> 644         lambda params: fit_function(params),
#     645         self.initial_parameters(data),
#     646         full_output=1,
#     647         disp=False)
#     648 self.parameters(parameters)
#     649 if not self.in_range():
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:635, in Distribution.fit.<locals>.fit_function(params)
#     633 def fit_function(params):
#     634     self.parameters(params)
# --> 635     return -sum(self.loglikelihoods(data))
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:964, in Distribution.loglikelihoods(self, data)
#     959 """
#     960 The logarithm of the likelihoods of the observed data from the
#     961 theoretical distribution.
#     962 """
#     963 from numpy import log
# --> 964 return log(self.likelihoods(data))
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:956, in Distribution.likelihoods(self, data)
#     951 def likelihoods(self, data):
#     952     """
#     953     The likelihoods of the observed data from the theoretical distribution.
#     954     Another name for the probabilities or probability density function.
#     955     """
# --> 956     return self.pdf(data)
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:825, in Distribution.pdf(self, data)
#     823 if data is None and hasattr(self, 'parent_Fit'):
#     824     data = self.parent_Fit.data
# --> 825 data = trim_to_range(data, xmin=self.xmin, xmax=self.xmax)
#     826 n = len(data)
#     827 from sys import float_info
#
# File ~\anaconda3\lib\site-packages\powerlaw.py:1927, in trim_to_range(data, xmin, xmax, **kwargs)
#    1925 data = asarray(data)
#    1926 if xmin:
# -> 1927     data = data[data>=xmin]
#    1928 if xmax:
#    1929     data = data[data<=xmax]
#
# KeyboardInterrupt:

# %%
Dmyfit =  fit.power_law.D
Ds = np.array(Ds)
pvalue = np.sum(Dmyfit <= Ds)/len(Ds)
pvalue # must be higher than e.g. 0.1
## forse mi dava sempre 1 anche in tesi
# Out:
# 0.29

# %%
plt.hist(Ds, bins = 34,color = 'grey')
plt.vlines(Dmyfit, 0,10,color ='red')
plt.xlabel('Ds')
plt.ylabel('pdf');
## il range di fit è piccolo..

# %% [markdown]
# ## Martin Gerlach Testing Statistical Laws in Complex Systems package

# %% [markdown]
# ## (I have renaimed powerlaw.py module into power.py otherwise there is conflict with powerlaw by Alstott)

# %%
os.chdir("C:/Users/Benedetta/Desktop/Criticality in barrel cortex/")

# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.cm as cm
cmap = cm.tab10
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_io_ts import *
from stats import xdata_to_xnx, x_autocorr_sm_ext
from powerlaw_fit import *


# import setup for figure layout (see src/modules_plotting.py to customize)
from modules_plotting import *

# %%
xmin_found = fit.power_law.xmin
xmax = max(data)
n = len(data)

# %%
x_data = data
xmin = xmin_found
x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)

N = np.sum(nx)
px = nx/N
Fx = 1-np.cumsum(px)

## Fit: powerlaw
if value == True:
    print('here')
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_disc(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_disc(x,xmin,xmax,alpha)
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_cont(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_cont(x,xmin,xmax,alpha) ### GIUSTO COSì
alpha ## differenze.....
# Out:
# 1.6781089104729463

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

## Plot the distribution
x_ = x
y_ = Fx

c_ = cmap(0)
ax.plot(x_,y_,marker='o',ms=2,lw=0,c = c_,label = 'Data')

## Plot the fit
c_ = cmap(1)
x_ = x
y_ = Fx_fit
plt.plot(x_,y_,lw=2,c=c_, label = 'Fit')

ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel(r'$x$')#,labelpad=0)
ax.set_ylabel(r'$p(x)$')
ax.set_ylim(10**-6,10**0)
# Out:
# (1e-06, 1)

# %%
xmin_found
# Out:
# 0.01999999999998181

# %%
x_data = data
xmin = xmin_found
x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)

N = np.sum(nx)
px = nx/N
Fx = 1-np.cumsum(px)

## Fit: powerlaw
if value == True:
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_disc(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_disc(x,xmin,xmax,alpha) ### GIUSTO COSì
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax)
    alpha = result['alpha']
    px_fit = pdf_power_cont(x,xmin,xmax,alpha)
    Fx_fit = 1 - cdf_power_cont(x,xmin,xmax,alpha)


fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

## Plot the distribution
x_ = x
y_ = px

c_ = cmap(0)
ax.plot(x_,y_,marker='o',ms=2,lw=0.1,c = c_,label = 'Data')

## Plot the fit
c_ = cmap(1)
x_ = x
y_ = px_fit
plt.plot(x_,y_,lw=2,c=c_, label = 'Fit')

ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(10**-3,10**-1)

ax.set_xlabel(r'$x$')#,labelpad=0)
ax.set_ylabel(r'$p(x)$')
# Out:
# Text(0, 0.5, '$p(x)$')

# %%
np.random.seed(42)

nrep = 10**3
q1,q2 = 1,99
result = x_autocorr_sm_ext(np.log(x_data),nrep=nrep,q=[q1,q2])
x = result['tau']
y_mu,y_1,y_2 = result['C']
y_mu_rand,y_1_rand,y_2_rand = result['C_rand']

## here we calculate from t=0,1,...,t^* where t^* is the first point
## where true C(t) is within the q-percentiles of the random

# ind_t_star = np.where( (y_mu<=y_2_rand)&(y_mu>=y_1_rand) )[0][1]
ind_t_star = np.where(y_1<=y_2_rand)[0][2]
tau_star = x[ind_t_star]

print('Autocorrelation time: ',tau_star)
# Out:
# Autocorrelation time:  115

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)#, figsize=fig_size)

alpha_val = .5
## Plot the empirical autocorrelation
x_ = x
y_ = y_mu
z1_ = y_1
z2_ = y_2
c_ = cmap(0)
ax.plot(x_,y_,c = c_,lw=lw, label = 'Data')
ax.fill_between(x_,z1_,z2_,color=c_,alpha=alpha_val,lw=0)



## Plot the randomized autocorrelation
x_ = x
y_ = y_mu_rand
z1_ = y_1_rand
z2_ = y_2_rand
c_ = cmap(1)
ax.plot(x_,y_,c = c_,lw=lw, label = 'Randomized')
ax.fill_between(x_,z1_,z2_,color=c_,alpha=alpha_val,lw=0)


ax.plot([tau_star,tau_star],[-1,1],lw=1,color='black',ls=':')


## Layout stuff
ax.legend(loc='upper right')

ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel(r'Time Lag, $\tau$')#,labelpad=0)
ax.set_ylabel(r'$C(\tau)$')
#ax.set_ylim(-0.1,0.2)


x_annot_tau = 0.8
y_annot_tau = 0.6
ax.annotate(r'$\tau^*=%s$'%(int(tau_star)),xy=(x_annot_tau,y_annot_tau),xycoords = 'axes fraction')
# Out:
# Text(0.8, 0.6, '$\\tau^*=115$')

# %%
#result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep)
#result

# %%
xmin,xmax
# Out:
# (0.01999999999998181, 0.5800000000000054)

# %%
nrep_synth = 100 ## number of synthetic datasets to generate for empirical p-value (i have called this niter above)

x,nx = xdata_to_xnx(x_data,norm=False,xmin=xmin,xmax=xmax)
if value == True:
    result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
else:
    result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
    
    
alpha = result['alpha'] ## fitted parameter alpha
pval = result['pval'] ## p-value
KS = result['KS'] ## KS-distance

print('Original dataset. N = %s'%(N))
print('Empirical p-value from %s synthetic datasets: '%(nrep_synth), pval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 7
#       5     result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
#       6 else:
# ----> 7     result = fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
#      10 alpha = result['alpha'] ## fitted parameter alpha
#      11 pval = result['pval'] ## p-value
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:116, in fit_power_cont_sign(x, nx, xmin, xmax, a0, nrep_synth)
#     114 x_data_synth = draw_power_cont(int(N),xmin,xmax,alpha_fit)
#     115 x_synth,nx_synth = xdata_to_xnx(x_data_synth)
# --> 116 result_synth = fit_power_cont_wrapper(x_synth,nx_synth,xmin,xmax,a0=a0)
#     117 alpha_synth+=[result_synth['alpha']]
#     118 L_synth+=[result_synth['L']]
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:139, in fit_power_cont_wrapper(x, nx, xmin, xmax, a0)
#     137 ## KS - test -- perhaps improve this one?
#     138 px = nx/float(np.sum(nx))
# --> 139 KS = KS_pow(x,px,alpha_fit,xmin,xmax,cont=True)
#     141 L = logL_power_cont(x,nx,xmin,xmax,alpha_fit)
#     143 result = {}
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:175, in KS_pow(x_emp, px_emp, a, xmin, xmax, cont)
#     172 if cont==True:
#     173     ## continuous powerlaw
#     174     Fx_true = cdf_power_cont(x_emp,xmin,xmax,a)
# --> 175     KS_plus = np.max(np.abs( Fx_emp[:-1] - Fx_true[1:] ))
#     176     KS_minus = np.max(np.abs( Fx_emp - Fx_true ))
#     178 else:
#     179     ## discrete powerlaw
#     180     # D_plus
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2754, in amax(a, axis, out, keepdims, initial, where)
#    2638 @array_function_dispatch(_amax_dispatcher)
#    2639 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2640          where=np._NoValue):
#    2641     """
#    2642     Return the maximum of an array or maximum along an axis.
#    2643
#    (...)
#    2752     5
#    2753     """
# -> 2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2755                           keepdims=keepdims, initial=initial, where=where)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
p_sub = 1./tau_star ## 0 ... 1 (keep nothing ... keep all); we set 1/tau_star
N_sub = int(p_sub*N)
nrep_synth = 100 ## number of synthetic datasets to generate for empirical p-value


## subsample -- take N_sub samples from x_data without replacement
x_data_sub = np.random.choice(x_data,size=N_sub,replace=False)
x,nx = xdata_to_xnx(x_data_sub,norm=False,xmin=xmin,xmax=xmax)
result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth) if value else fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)

alpha = result['alpha'] ## fitted parameter alpha
pval = result['pval'] ## p-value
KS = result['KS'] ## KS-distance

print(r'Subsampled dataset: n = %s (n/N ~ %s)'%(N_sub,p_sub)) 
print('Empirical p-value from %s synthetic datasets: '%(nrep_synth), pval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 9
#       7 x_data_sub = np.random.choice(x_data,size=N_sub,replace=False)
#       8 x,nx = xdata_to_xnx(x_data_sub,norm=False,xmin=xmin,xmax=xmax)
# ----> 9 result = fit_power_disc_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth) if value else fit_power_cont_sign(x,nx,xmin=xmin,xmax=xmax,nrep_synth=nrep_synth)
#      11 alpha = result['alpha'] ## fitted parameter alpha
#      12 pval = result['pval'] ## p-value
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:116, in fit_power_cont_sign(x, nx, xmin, xmax, a0, nrep_synth)
#     114 x_data_synth = draw_power_cont(int(N),xmin,xmax,alpha_fit)
#     115 x_synth,nx_synth = xdata_to_xnx(x_data_synth)
# --> 116 result_synth = fit_power_cont_wrapper(x_synth,nx_synth,xmin,xmax,a0=a0)
#     117 alpha_synth+=[result_synth['alpha']]
#     118 L_synth+=[result_synth['L']]
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:139, in fit_power_cont_wrapper(x, nx, xmin, xmax, a0)
#     137 ## KS - test -- perhaps improve this one?
#     138 px = nx/float(np.sum(nx))
# --> 139 KS = KS_pow(x,px,alpha_fit,xmin,xmax,cont=True)
#     141 L = logL_power_cont(x,nx,xmin,xmax,alpha_fit)
#     143 result = {}
#
# File ~\Desktop\Criticality in barrel cortex\powerlaw_fit.py:175, in KS_pow(x_emp, px_emp, a, xmin, xmax, cont)
#     172 if cont==True:
#     173     ## continuous powerlaw
#     174     Fx_true = cdf_power_cont(x_emp,xmin,xmax,a)
# --> 175     KS_plus = np.max(np.abs( Fx_emp[:-1] - Fx_true[1:] ))
#     176     KS_minus = np.max(np.abs( Fx_emp - Fx_true ))
#     178 else:
#     179     ## discrete powerlaw
#     180     # D_plus
#
# File <__array_function__ internals>:5, in amax(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2754, in amax(a, axis, out, keepdims, initial, where)
#    2638 @array_function_dispatch(_amax_dispatcher)
#    2639 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2640          where=np._NoValue):
#    2641     """
#    2642     Return the maximum of an array or maximum along an axis.
#    2643
#    (...)
#    2752     5
#    2753     """
# -> 2754     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2755                           keepdims=keepdims, initial=initial, where=where)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity
