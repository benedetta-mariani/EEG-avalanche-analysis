# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Benedetta\\Desktop\\Criticality in barrel cortex\\EEG avalanche analysis'

# %%
fl1=pd.read_table("../numpy files/bb11s2.dat", sep="\s+", header = None)

# %%
t=np.arange(0,len(fl1)/500,0.002)

# %%
# Out:
# 189.738

# %%
fl1 = np.asarray(fl1)
fl1.shape
# Out:
# (94870, 10)

# %%
for i in range(10):
    plt.plot(t,fl1[:,i])
plt.xlabel('Time')
plt.ylabel('SD');

# %%
type(t), type(fl1)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
plt.plot(t,fl1[:,0], color="red")
plt.plot(t[np.abs(fl1[:,0])>1],fl1[:,0][np.abs(fl1[:,0])>1], '.',color="black", markersize = '1.5') ## here some correction
plt.xlabel('Time')
plt.ylabel('SD')
plt.xlim(0,50);
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
final_t = np.array(np.array(np.abs(fl1[:,0]) > 1, dtype = float) 
                   + np.array(np.abs(fl1[:,1]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,2]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,3]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,4]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,5]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,6]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,7]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,8]) > 1, dtype = float)
                   + np.array(np.abs(fl1[:,9]) > 1, dtype = float), dtype = bool)

# %%
final_t = np.array(final_t, dtype = float)

# %%
for i in range(10):
    plt.plot(t,fl1[:, i])
#
plt.vlines(t[np.array(final_t, dtype = bool)],-10,10, alpha =   0.1)
plt.xlabel('Time[s]')
plt.ylabel('SD');
plt.xlim(0.,1);

# %%
len(final_t)
# Out:
# 94870

# %%
av_indice_start = np.where((final_t[1:] - final_t[:-1]) >0)[0]### these are the indices where an avalanche begins
av_indice_end = np.where((final_t[1:] - final_t[:-1])< 0)[0]### these are the indices where an avalanche ends

# %%
for i in range(10):
    plt.plot(t,fl1[:,i])

plt.vlines(t[av_indice_start],-10,10, color = 'green')
plt.vlines(t[av_indice_end],-10,10, color = 'red')

#plt.vlines(t[np.array(final_t, dtype = bool)],-10,10, alpha =   0.3)

plt.hlines(1, 0,180,'b')
plt.hlines(-1, 0,180,'b')

#plt.hlines(np.std(x2), 0,T,'b')
#plt.hlines(-np.std(x2), 0,T,'b')

plt.xlabel('Time[s]')
plt.ylabel('SD');
plt.xlim(10,11);

# %%
len(av_indice_start), len(av_indice_end)
# Out:
# (1058, 1059)

# %%
flag = True if len(av_indice_start) < len(av_indice_end) else False
if flag:
    av_indice_start = np.insert(av_indice_start,0,0) ## I corrected here
    
if not flag:
    #print(av_indice_end)
    av_indice_end = np.append(av_indice_end,len(fl1[:,0])-1)

# %%
len(av_indice_end),len(av_indice_start)
# Out:
# (1059, 1059)

# %%
global_signal = (np.abs(fl1[:,0])+ 
                 np.abs(fl1[:,1])+ 
                 np.abs(fl1[:,2])+
                 np.abs(fl1[:,3])+
                 np.abs(fl1[:,4])+
                 np.abs(fl1[:,5])+
                 np.abs(fl1[:,6])+
                 np.abs(fl1[:,7])+
                 np.abs(fl1[:,8])+
                 np.abs(fl1[:,9]))

avalanche_sizes = []
avalanche_dur = []

for s in range(len(av_indice_start)):
    if len(av_indice_start) != len(av_indice_end):
        print('Error, they must be of the same length')
        break
    avalanche_sizes.append(np.sum(global_signal[av_indice_start[s]:av_indice_end[s]]))
    avalanche_dur.append(t[av_indice_end[s]]- t[av_indice_start[s]])

# %%
avalanche_dur
# Out:
# [0.134,
#  0.176,
#  0.27799999999999997,
#  0.388,
#  0.508,
#  0.018000000000000016,
#  0.56,
#  0.03600000000000003,
#  0.23399999999999999,
#  0.1120000000000001,
#  0.3440000000000003,
#  0.12799999999999967,
#  0.038000000000000256,
#  0.15000000000000036,
#  0.1459999999999999,
#  0.07800000000000029,
#  0.017999999999999794,
#  0.0259999999999998,
#  0.02200000000000024,
#  0.040000000000000036,
#  0.0519999999999996,
#  0.07399999999999984,
#  0.02799999999999958,
#  0.14400000000000013,
#  0.07400000000000073,
#  0.20400000000000063,
#  0.041999999999999815,
#  0.25,
#  0.02799999999999958,
#  0.036000000000000476,
#  0.0259999999999998,
#  0.017999999999999794,
#  0.05600000000000005,
#  0.05999999999999961,
#  0.02400000000000002,
#  0.2999999999999998,
#  0.1980000000000004,
#  0.15200000000000014,
#  0.02400000000000002,
#  0.35800000000000054,
#  0.006000000000000227,
#  0.03199999999999914,
#  0.05600000000000005,
#  0.02800000000000047,
#  0.08599999999999941,
#  0.008000000000000007,
#  0.07399999999999984,
#  0.03799999999999848,
#  0.0519999999999996,
#  0.02999999999999936,
#  0.07600000000000051,
#  0.09800000000000075,
#  0.02999999999999936,
#  0.12400000000000055,
#  0.023999999999999133,
#  0.03200000000000003,
#  0.04399999999999871,
#  0.13599999999999923,
#  0.34999999999999964,
#  0.02200000000000024,
#  0.532,
#  0.41799999999999926,
#  0.08200000000000074,
#  0.2240000000000002,
#  0.40199999999999925,
#  0.3460000000000001,
#  0.33999999999999986,
#  0.023999999999999133,
#  0.038000000000000256,
#  0.7240000000000002,
#  0.33800000000000097,
#  0.05400000000000027,
#  0.1819999999999986,
#  0.011999999999998678,
#  0.8719999999999999,
#  0.04400000000000048,
#  0.2740000000000009,
#  0.18599999999999994,
#  0.18200000000000038,
#  0.7779999999999987,
#  0.0519999999999996,
#  0.1039999999999992,
#  0.1980000000000004,
#  0.10000000000000142,
#  0.01799999999999713,
#  0.02400000000000091,
#  0.17800000000000082,
#  0.11599999999999966,
#  0.1839999999999975,
#  0.003999999999997783,
#  0.08200000000000074,
#  0.038000000000000256,
#  0.15400000000000347,
#  0.2099999999999973,
#  0.03200000000000003,
#  0.13799999999999812,
#  0.007999999999999119,
#  0.17999999999999972,
#  0.26399999999999935,
#  0.24200000000000088,
#  0.13599999999999923,
#  0.19000000000000128,
#  0.07199999999999918,
#  0.036000000000001364,
#  0.4740000000000002,
#  0.07400000000000162,
#  0.36799999999999855,
#  0.20800000000000196,
#  0.1699999999999875,
#  0.02400000000000091,
#  0.03999999999999204,
#  0.036000000000001364,
#  0.12600000000000477,
#  0.060000000000002274,
#  0.04599999999999227,
#  0.07200000000000273,
#  0.020000000000010232,
#  0.056000000000011596,
#  0.038000000000010914,
#  0.02400000000000091,
#  0.06799999999998363,
#  0.06200000000001182,
#  0.038000000000010914,
#  0.038000000000010914,
#  0.09000000000000341,
#  0.0619999999999834,
#  0.004000000000019099,
#  0.055999999999983174,
#  0.036000000000001364,
#  0.014000000000010004,
#  0.06399999999999295,
#  0.030000000000001137,
#  0.033999999999991815,
#  0.04999999999998295,
#  0.06399999999999295,
#  0.07999999999998408,
#  0.11599999999998545,
#  0.8559999999999945,
#  0.02600000000001046,
#  0.04999999999998295,
#  0.009999999999990905,
#  0.2259999999999991,
#  0.02800000000002001,
#  0.11400000000000432,
#  0.05000000000001137,
#  0.14400000000000546,
#  0.04599999999999227,
#  0.009999999999990905,
#  0.030000000000001137,
#  0.040000000000020464,
#  0.029999999999972715,
#  0.036000000000001364,
#  0.14799999999999613,
#  0.0660000000000025,
#  0.03799999999998249,
#  0.05000000000001137,
#  0.06800000000001205,
#  0.06799999999998363,
#  0.020000000000010232,
#  0.05000000000001137,
#  0.0519999999999925,
#  0.02199999999999136,
#  0.18999999999999773,
#  0.009999999999990905,
#  0.04599999999999227,
#  0.40800000000001546,
#  0.18600000000000705,
#  0.32800000000000296,
#  0.003999999999990678,
#  0.027999999999991587,
#  0.015999999999991132,
#  0.018000000000000682,
#  0.0800000000000125,
#  0.07800000000000296,
#  0.28000000000000114,
#  0.02400000000000091,
#  0.036000000000001364,
#  0.20199999999999818,
#  0.031999999999982265,
#  0.02400000000000091,
#  0.25200000000000955,
#  0.09200000000001296,
#  0.02800000000002001,
#  0.04800000000000182,
#  0.12400000000002365,
#  0.06800000000001205,
#  0.08199999999999363,
#  0.054000000000002046,
#  0.008000000000009777,
#  0.027999999999991587,
#  0.06400000000002137,
#  0.16800000000000637,
#  0.02800000000002001,
#  0.009999999999990905,
#  0.04200000000000159,
#  0.02400000000000091,
#  0.007999999999981355,
#  0.07200000000000273,
#  0.02199999999999136,
#  0.038000000000010914,
#  0.04600000000002069,
#  0.03200000000001069,
#  0.03200000000001069,
#  0.04200000000000159,
#  0.027999999999991587,
#  0.02199999999999136,
#  0.21600000000000819,
#  0.013999999999981583,
#  0.016000000000019554,
#  0.03999999999999204,
#  0.16800000000000637,
#  0.038000000000010914,
#  0.03799999999998249,
#  0.031999999999982265,
#  0.02199999999999136,
#  0.0519999999999925,
#  0.11800000000002342,
#  0.054000000000002046,
#  0.04800000000000182,
#  0.02400000000000091,
#  0.03200000000001069,
#  0.06200000000001182,
#  0.07600000000002183,
#  0.030000000000001137,
#  0.03200000000001069,
#  0.030000000000001137,
#  0.04400000000001114,
#  0.04399999999998272,
#  0.09400000000002251,
#  0.033999999999991815,
#  0.057999999999992724,
#  0.018000000000000682,
#  0.1519999999999868,
#  0.010000000000019327,
#  0.04999999999998295,
#  ...]
